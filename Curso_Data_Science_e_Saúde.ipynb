# %%
import pandas as pd

confirmed = pd.read_csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_19-covid-Confirmed.csv")
confirmed.head()
# Out:
#   Province/State  Country/Region      Lat  ...  2/29/20  3/1/20  3/2/20
# 0          Anhui  Mainland China  31.8257  ...      990     990     990
# 1        Beijing  Mainland China  40.1824  ...      411     413     414
# 2      Chongqing  Mainland China  30.0572  ...      576     576     576
# 3         Fujian  Mainland China  26.0789  ...      296     296     296
# 4          Gansu  Mainland China  36.0611  ...       91      91      91
#
# [5 rows x 45 columns]

# %%
confirmed.shape
# Out:
# (142, 45)

# %%
last_date = "3/2/20"

confirmed[last_date]
# Out:
# 0      990
# 1      414
# 2      576
# 3      296
# 4       91
#       ...
# 137      1
# 138      1
# 139      1
# 140      1
# 141      1
# Name: 3/2/20, Length: 142, dtype: int64

# %%
confirmed["Country/Region"]
# Out:
# 0      Mainland China
# 1      Mainland China
# 2      Mainland China
# 3      Mainland China
# 4      Mainland China
#             ...
# 137                US
# 138                US
# 139                US
# 140                US
# 141                US
# Name: Country/Region, Length: 142, dtype: object

# %%
confirmed["Country/Region"].unique()
# Out:
# array(['Mainland China', 'Thailand', 'Japan', 'South Korea', 'Taiwan',
#        'US', 'Macau', 'Hong Kong', 'Singapore', 'Vietnam', 'France',
#        'Nepal', 'Malaysia', 'Canada', 'Australia', 'Cambodia',
#        'Sri Lanka', 'Germany', 'Finland', 'United Arab Emirates',
#        'Philippines', 'India', 'Italy', 'UK', 'Russia', 'Sweden', 'Spain',
#        'Belgium', 'Others', 'Egypt', 'Iran', 'Lebanon', 'Iraq', 'Oman',
#        'Afghanistan', 'Bahrain', 'Kuwait', 'Algeria', 'Croatia',
#        'Switzerland', 'Austria', 'Israel', 'Pakistan', 'Brazil',
#        'Georgia', 'Greece', 'North Macedonia', 'Norway', 'Romania',
#        'Denmark', 'Estonia', 'Netherlands', 'San Marino', 'Belarus',
#        'Iceland', 'Lithuania', 'Mexico', 'New Zealand', 'Nigeria',
#        'Ireland', 'Luxembourg', 'Monaco', 'Qatar', 'Ecuador',
#        'Azerbaijan', 'Czech Republic', 'Armenia', 'Dominican Republic',
#        'Indonesia', 'Portugal', 'Andorra', 'Latvia', 'Morocco',
#        'Saudi Arabia', 'Senegal'], dtype=object)

# %%
confirmed["Province/State"].unique()
# Out:
# array(['Anhui', 'Beijing', 'Chongqing', 'Fujian', 'Gansu', 'Guangdong',
#        'Guangxi', 'Guizhou', 'Hainan', 'Hebei', 'Heilongjiang', 'Henan',
#        'Hubei', 'Hunan', 'Inner Mongolia', 'Jiangsu', 'Jiangxi', 'Jilin',
#        'Liaoning', 'Ningxia', 'Qinghai', 'Shaanxi', 'Shandong',
#        'Shanghai', 'Shanxi', 'Sichuan', 'Tianjin', 'Tibet', 'Xinjiang',
#        'Yunnan', 'Zhejiang', nan, 'Taiwan', 'King County, WA',
#        'Cook County, IL', 'Tempe, AZ', 'Macau', 'Hong Kong',
#        'Toronto, ON', 'British Columbia', 'Orange, CA', 'Los Angeles, CA',
#        'New South Wales', 'Victoria', 'Queensland', 'London, ON',
#        'Santa Clara, CA', 'South Australia', 'Boston, MA',
#        'San Benito, CA', 'Madison, WI', 'Diamond Princess cruise ship',
#        'San Diego County, CA', 'San Antonio, TX',
#        'Omaha, NE (From Diamond Princess)',
#        'Travis, CA (From Diamond Princess)', 'From Diamond Princess',
#        'Lackland, TX (From Diamond Princess)', 'Humboldt County, CA',
#        'Sacramento County, CA',
#        'Unassigned Location (From Diamond Princess)', ' Montreal, QC',
#        'Western Australia', 'Portland, OR', 'Snohomish County, WA',
#        'Providence, RI', 'Tasmania', 'Grafton County, NH',
#        'Hillsborough, FL', 'New York City, NY', 'Placer County, CA',
#        'San Mateo, CA', 'Sarasota, FL', 'Sonoma County, CA',
#        'Umatilla, OR'], dtype=object)

# %%
confirmed.sample(20)
# Out:
#                                   Province/State  ... 3/2/20
# 31                                           NaN  ...     43
# 126                                          NaN  ...      2
# 88                                           NaN  ...     56
# 112                            Western Australia  ...      2
# 91                                           NaN  ...     42
# 60                                           NaN  ...   2036
# 84   Unassigned Location (From Diamond Princess)  ...     45
# 85                                           NaN  ...      6
# 18                                      Liaoning  ...    122
# 17                                         Jilin  ...     93
# 50                                      Victoria  ...      9
# 76             Omaha, NE (From Diamond Princess)  ...      0
# 19                                       Ningxia  ...     74
# 12                                         Hubei  ...  67103
# 11                                         Henan  ...   1272
# 72                          San Diego County, CA  ...      2
# 27                                         Tibet  ...      1
# 97                                           NaN  ...      7
# 46                              British Columbia  ...      8
# 29                                        Yunnan  ...    174
#
# [20 rows x 45 columns]

# %%
confirmed.iloc[1]
# Out:
# Province/State           Beijing
# Country/Region    Mainland China
# Lat                      40.1824
# Long                     116.414
# 1/22/20                       14
# 1/23/20                       22
# 1/24/20                       36
# 1/25/20                       41
# 1/26/20                       68
# 1/27/20                       80
# 1/28/20                       91
# 1/29/20                      111
# 1/30/20                      114
# 1/31/20                      139
# 2/1/20                       168
# 2/2/20                       191
# 2/3/20                       212
# 2/4/20                       228
# 2/5/20                       253
# 2/6/20                       274
# 2/7/20                       297
# 2/8/20                       315
# 2/9/20                       326
# 2/10/20                      337
# 2/11/20                      342
# 2/12/20                      352
# 2/13/20                      366
# 2/14/20                      372
# 2/15/20                      375
# 2/16/20                      380
# 2/17/20                      381
# 2/18/20                      387
# 2/19/20                      393
# 2/20/20                      395
# 2/21/20                      396
# 2/22/20                      399
# 2/23/20                      399
# 2/24/20                      399
# 2/25/20                      400
# 2/26/20                      400
# 2/27/20                      410
# 2/28/20                      410
# 2/29/20                      411
# 3/1/20                       413
# 3/2/20                       414
# Name: 1, dtype: object

# %%
confirmed.set_index("Province/State").loc["Anhui"]
# Out:
# Country/Region    Mainland China
# Lat                      31.8257
# Long                     117.226
# 1/22/20                        1
# 1/23/20                        9
# 1/24/20                       15
# 1/25/20                       39
# 1/26/20                       60
# 1/27/20                       70
# 1/28/20                      106
# 1/29/20                      152
# 1/30/20                      200
# 1/31/20                      237
# 2/1/20                       297
# 2/2/20                       340
# 2/3/20                       408
# 2/4/20                       480
# 2/5/20                       530
# 2/6/20                       591
# 2/7/20                       665
# 2/8/20                       733
# 2/9/20                       779
# 2/10/20                      830
# 2/11/20                      860
# 2/12/20                      889
# 2/13/20                      910
# 2/14/20                      934
# 2/15/20                      950
# 2/16/20                      962
# 2/17/20                      973
# 2/18/20                      982
# 2/19/20                      986
# 2/20/20                      987
# 2/21/20                      988
# 2/22/20                      989
# 2/23/20                      989
# 2/24/20                      989
# 2/25/20                      989
# 2/26/20                      989
# 2/27/20                      989
# 2/28/20                      990
# 2/29/20                      990
# 3/1/20                       990
# 3/2/20                       990
# Name: Anhui, dtype: object

# %%
confirmed.set_index("Province/State").iloc[1]
# Out:
# Country/Region    Mainland China
# Lat                      40.1824
# Long                     116.414
# 1/22/20                       14
# 1/23/20                       22
# 1/24/20                       36
# 1/25/20                       41
# 1/26/20                       68
# 1/27/20                       80
# 1/28/20                       91
# 1/29/20                      111
# 1/30/20                      114
# 1/31/20                      139
# 2/1/20                       168
# 2/2/20                       191
# 2/3/20                       212
# 2/4/20                       228
# 2/5/20                       253
# 2/6/20                       274
# 2/7/20                       297
# 2/8/20                       315
# 2/9/20                       326
# 2/10/20                      337
# 2/11/20                      342
# 2/12/20                      352
# 2/13/20                      366
# 2/14/20                      372
# 2/15/20                      375
# 2/16/20                      380
# 2/17/20                      381
# 2/18/20                      387
# 2/19/20                      393
# 2/20/20                      395
# 2/21/20                      396
# 2/22/20                      399
# 2/23/20                      399
# 2/24/20                      399
# 2/25/20                      400
# 2/26/20                      400
# 2/27/20                      410
# 2/28/20                      410
# 2/29/20                      411
# 3/1/20                       413
# 3/2/20                       414
# Name: Beijing, dtype: object

# %%
# valor falso pois o erro é muito grande
# não vou considerar essa analise pois tem muito campo vazio (muita disparidade no padrão)

confirmed["Country/Region"].value_counts()
# Out:
# Mainland China     31
# US                 29
# Australia           7
# Canada              4
# Hong Kong           1
#                    ..
# Philippines         1
# North Macedonia     1
# Brazil              1
# Ireland             1
# Finland             1
# Name: Country/Region, Length: 75, dtype: int64

# %%
confirmed_by_country = confirmed.groupby("Country/Region").sum()
confirmed_by_country.head()
# Out:
#                      Lat      Long  1/22/20  ...  2/29/20  3/1/20  3/2/20
# Country/Region                               ...
# Afghanistan      33.0000   65.0000        0  ...        1       1       1
# Algeria          28.0339    1.6596        0  ...        1       1       3
# Andorra          42.5063    1.5218        0  ...        0       0       1
# Armenia          40.0691   45.0382        0  ...        0       1       1
# Australia      -172.5889  989.6423        0  ...       25      27      30
#
# [5 rows x 43 columns]

# %%
confirmed_by_country.sample(10)
# Out:
#                     Lat      Long  1/22/20  ...  2/29/20  3/1/20  3/2/20
# Country/Region                              ...
# Lebanon         33.8547   35.8623        0  ...        4      10      13
# Nigeria          9.0820    8.6753        0  ...        1       1       1
# Iran            32.0000   53.0000        0  ...      593     978    1501
# Netherlands     52.1326    5.2913        0  ...        6      10      18
# Germany         51.0000    9.0000        0  ...       79     130     159
# Austria         47.5162   14.5501        0  ...        9      14      18
# Indonesia       -0.7893  113.9213        0  ...        0       0       2
# Qatar           25.3548   51.1839        0  ...        1       3       3
# Iceland         64.9631  -19.0208        0  ...        1       3       6
# Others          35.4437  139.6380        0  ...      705     705     705
#
# [10 rows x 43 columns]

# %%
confirmed_by_country.loc["Mainland China"][2:]
# Out:
# 1/22/20      547.0
# 1/23/20      639.0
# 1/24/20      916.0
# 1/25/20     1399.0
# 1/26/20     2062.0
# 1/27/20     2863.0
# 1/28/20     5494.0
# 1/29/20     6070.0
# 1/30/20     8124.0
# 1/31/20     9783.0
# 2/1/20     11871.0
# 2/2/20     16607.0
# 2/3/20     19693.0
# 2/4/20     23680.0
# 2/5/20     27409.0
# 2/6/20     30553.0
# 2/7/20     34075.0
# 2/8/20     36778.0
# 2/9/20     39790.0
# 2/10/20    42306.0
# 2/11/20    44327.0
# 2/12/20    44699.0
# 2/13/20    59832.0
# 2/14/20    66292.0
# 2/15/20    68347.0
# 2/16/20    70446.0
# 2/17/20    72364.0
# 2/18/20    74139.0
# 2/19/20    74546.0
# 2/20/20    74999.0
# 2/21/20    75472.0
# 2/22/20    76922.0
# 2/23/20    76938.0
# 2/24/20    77152.0
# 2/25/20    77660.0
# 2/26/20    78065.0
# 2/27/20    78498.0
# 2/28/20    78824.0
# 2/29/20    79251.0
# 3/1/20     79826.0
# 3/2/20     80026.0
# Name: Mainland China, dtype: float64

# %%
confirmed_by_country.loc["Mainland China"][2:].plot()
